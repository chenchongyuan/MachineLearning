# %% [markdown]
# # SVM
# 1. 描述：SVM(Support Vector Machine)指的是支持向量机，是常见的一种判别方法。在机器学习领域，是一个有监督的学习模型，通常用来进行模式识别、分类以及回归分析。
# 2. linear Hard Margin SVM
#     - ![SVM_deduction1.jpg](attachment:SVM_deduction1.jpg)
#     - ![SVM_deduction2.jpg](attachment:SVM_deduction2.jpg)
#     - ![SVM_deduction3.jpg](attachment:SVM_deduction3.jpg)
#     - ![SVM_deduction4.jpg](attachment:SVM_deduction4.jpg)
#     - ![SVM_deduction5.jpg](attachment:SVM_deduction5.jpg)
#     - 这里将wd、bd用w、b换元表示
#     ![SVM_deduction6.jpg](attachment:SVM_deduction6.jpg)
#     - ![SVM_deduction7.jpg](attachment:SVM_deduction7.jpg)
#     - ![SVM_deduction8.jpg](attachment:SVM_deduction8.jpg)
# 3. linear Soft Margin SVM
#     - ![soft-margin-SVM1.jpg](attachment:soft-margin-SVM1.jpg)
#     - C越小，容错率越大
#     ![soft-margin-SVM2.jpg](attachment:soft-margin-SVM2.jpg)
# 4. 注意事项
#     - 由于涉及距离，所以要对数据进行归一化
# 5. 核函数（核技巧）
#     - ![SVM-kernel1.jpg](attachment:SVM-kernel1.jpg)
#     - ![SVM-kernel2.jpg](attachment:SVM-kernel2.jpg)
#     - ![SVM-kernel3.jpg](attachment:SVM-kernel3.jpg)
#     - ![SVM-kernel4.jpg](attachment:SVM-kernel4.jpg)
#     - ![SVM-kernel5.jpg](attachment:SVM-kernel5.jpg)
# 6. 高斯核
#     - ![SVM-RBFkernel1.jpg](attachment:SVM-RBFkernel1.jpg)
#     - ![SVM-RBFkernel2.jpg](attachment:SVM-RBFkernel2.jpg)
#     - ![SVM-RBFkernel3.jpg](attachment:SVM-RBFkernel3.jpg)
# 7. SVM思想解决回归问题
#     - ![SVM_regression.jpg](attachment:SVM_regression.jpg)

# %% [markdown]
# # sklearn中的SVM

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

iris = datasets.load_iris()
X = iris.data
y = iris.target

X = X[y < 2, :2]
y = y[y < 2]

# %%
plt.scatter(X[y==0, 0], X[y==0, 1])
plt.scatter(X[y==1, 0], X[y==1, 1])
plt.show()

# %% [markdown]
# ### 数据归一化（因为没做预测，所以未进行训练测试分离，下同）

# %%
from sklearn.preprocessing import StandardScaler

std_scaler = StandardScaler()
std_scaler.fit(X)
X_std = std_scaler.transform(X)

# %% [markdown]
# ### sklearn中的LinearSVC

# %% [markdown]
# ##### C=10000

# %%
from sklearn.svm import LinearSVC

svc = LinearSVC(C=1e4)
svc.fit(X_std, y)
# Out:
# LinearSVC(C=10000.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
svc.coef_  #返回系数，因为可以处理多分类问题，所以这是一个二维数组
# Out:
# array([[ 4.03077841, -2.49216156]])

# %%
svc.intercept_  #返回截距
# Out:
# array([ 0.95327681])

# %%
def plot_svc_decision_boundary(model, axis):
    x0, x1 = np.meshgrid(
        np.linspace(axis[0], axis[1], int((axis[1]-axis[0])*100)).reshape(-1, 1),
        np.linspace(axis[2], axis[3], int((axis[3]-axis[2])*100)).reshape(-1, 1)
    )
    X_new = np.c_[x0.ravel(), x1.ravel()]
    y_predict = model.predict(X_new)
    zz = y_predict.reshape(x0.shape)
    
    from matplotlib.colors import ListedColormap
    custom_cmap = ListedColormap(['#EF9A9A', '#FFF59D', '#90CAF9'])
    
    plt.contourf(x0, x1, zz, cmap=custom_cmap)
    
    #下面绘制margin的两条边界线
    w = model.coef_[0]  #二维数组所以取第一个元素数组
    b = model.intercept_[0]
    
    #决策边界直线：w0*x0 + w1*x1 + b = 0 ==> x1 = - w0/w1 * x0 - b/w1
    #上margin直线：w0*x0 + w1*x1 + b = 1 ==> x1 = - w0/w1 * x0 - b/w1 + 1/w1
    #下margin直线：w0*x0 + w1*x1 + b = -1 ==> x1 = - w0/w1 * x0 - b/w1 - 1/w1
    plot_x = np.linspace(axis[0], axis[1], 200)
    up_y = - w[0]/w[1] * plot_x - b/w[1] + 1/w[1]    #上边界
    down_y = - w[0]/w[1] * plot_x - b/w[1] - 1/w[1]  #下边界
    
    up_index = (up_y >= axis[2]) & (up_y <= axis[3]) #只绘制所设置坐标轴部分的图像
    down_index = (down_y >= axis[2]) & (down_y <= axis[3]) #适应坐标轴
    
    plt.plot(plot_x[up_index], up_y[up_index], color='yellow')
    plt.plot(plot_x[down_index], down_y[down_index], color='cyan')

# %%
plot_svc_decision_boundary(svc, axis=[-3, 3, -3, 3])
plt.scatter(X_std[y==0, 0], X_std[y==0, 1])
plt.scatter(X_std[y==1, 0], X_std[y==1, 1])
plt.show()

# %% [markdown]
# ##### C=0.01

# %%
svc2 = LinearSVC(C=0.01)
svc2.fit(X_std, y)
# Out:
# LinearSVC(C=0.01, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
plot_svc_decision_boundary(svc2, axis=[-3, 3, -3, 3])
plt.scatter(X_std[y==0, 0], X_std[y==0, 1])
plt.scatter(X_std[y==1, 0], X_std[y==1, 1])
plt.show()

# %% [markdown]
# # SVM中使用多项式特征

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

X, y = datasets.make_moons(noise=0.25)

# %%
plt.scatter(X[y==0, 0], X[y==0, 1])
plt.scatter(X[y==1, 0], X[y==1, 1])
plt.show()

# %% [markdown]
# ### 使用多项式特征的SVM

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline

def PolynomialSVC(degree, C=1.0):
    return Pipeline([
        ('poly', PolynomialFeatures(degree=degree)),
        ('std_scaler', StandardScaler()),
        ('lin_SVC', LinearSVC(C=C))
    ])

# %%
poly_svc = PolynomialSVC(degree=3)
poly_svc.fit(X, y)
# Out:
# Pipeline(memory=None,
#      steps=[('poly', PolynomialFeatures(degree=3, include_bias=True, interaction_only=False)), ('std_scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('lin_SVC', LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0))])

# %%
def plot_decision_boundary(model, axis):
    x0, x1 = np.meshgrid(
        np.linspace(axis[0], axis[1], int((axis[1]-axis[0])*100)).reshape(-1, 1),
        np.linspace(axis[2], axis[3], int((axis[3]-axis[2])*100)).reshape(-1, 1)
    )
    X_new = np.c_[x0.ravel(), x1.ravel()]
    y_predict = model.predict(X_new)
    zz = y_predict.reshape(x0.shape)
    
    from matplotlib.colors import ListedColormap
    custom_cmap = ListedColormap(['#EF9A9A', '#FFF59D', '#90CAF9'])
    
    plt.contourf(x0, x1, zz, cmap=custom_cmap)

# %%
plot_decision_boundary(poly_svc, axis=[-1.5, 2.5, -1.0, 1.5])
plt.scatter(X[y==0, 0], X[y==0, 1])
plt.scatter(X[y==1, 0], X[y==1, 1])
plt.show()

# %% [markdown]
# ### 使用多项式核函数的SVM

# %%
from sklearn.svm import SVC

def PolynomialKernelSVC(degree, C=1.0):
    return Pipeline([
        ('std_scaler', StandardScaler()),
        ('kernel_SVC', SVC(C=C, degree=degree, kernel='poly'))
    ])

# %%
poly_kernel_svc = PolynomialKernelSVC(degree=3)
poly_kernel_svc.fit(X, y)
# Out:
# Pipeline(memory=None,
#      steps=[('std_scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('kernel_SVC', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False))])

# %%
plot_decision_boundary(poly_kernel_svc, axis=[-1.5, 2.5, -1.0, 1.5])
plt.scatter(X[y==0, 0], X[y==0, 1])
plt.scatter(X[y==1, 0], X[y==1, 1])
plt.show()

# %% [markdown]
# # 简单理解高斯核函数

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(-4, 5, 1)
x
# Out:
# array([-4, -3, -2, -1,  0,  1,  2,  3,  4])

# %%
y = np.array((x >= -2) & (x <= 2), dtype='int')

# %%
y
# Out:
# array([0, 0, 1, 1, 1, 1, 1, 0, 0])

# %%
plt.scatter(x[y==0], [0]*len(x[y==0]))
plt.scatter(x[y==1], [0]*len(x[y==1]))
plt.show()

# %% [markdown]
# ### 编写简化高斯核函数

# %%
def guassian(x, l):
    gamma = 1.0
    return np.exp(- gamma * (x-l)**2)

# %%
l1, l2 = -1, 1

X_new = np.empty((len(x), 2))
for i, data in enumerate(x):
    X_new[i, 0] = guassian(data, l1)
    X_new[i, 1] = guassian(data, l2)

# %%
plt.scatter(X_new[y==0, 0], X_new[y==0, 1])
plt.scatter(X_new[y==1, 0], X_new[y==1, 1])
plt.show()

# %% [markdown]
# # 使用高斯核的SVM

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

X, y = datasets.make_moons(noise=0.25)

plt.scatter(X[y==0, 0], X[y==0, 1])
plt.scatter(X[y==1, 0], X[y==1, 1])
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline

def RBFKernelSVC(gamma=1.0):
    return Pipeline([
        ('std_scaler', StandardScaler()),
        ('svc', SVC(kernel='rbf', gamma=gamma))
    ])

# %%
def plot_decision_boundary(model, axis):
    x0, x1 = np.meshgrid(
        np.linspace(axis[0], axis[1], int((axis[1]-axis[0])*100)).reshape(-1, 1),
        np.linspace(axis[2], axis[3], int((axis[3]-axis[2])*100)).reshape(-1, 1)
    )
    X_new = np.c_[x0.ravel(), x1.ravel()]
    y_predict = model.predict(X_new)
    zz = y_predict.reshape(x0.shape)
    
    from matplotlib.colors import ListedColormap
    custom_cmap = ListedColormap(['#EF9A9A', '#FFF59D', '#90CAF9'])
    
    plt.contourf(x0, x1, zz, cmap=custom_cmap)

# %% [markdown]
# ##### gamma=1

# %%
svc_gamma1 = RBFKernelSVC(gamma=1.0)
svc_gamma1.fit(X, y)
# Out:
# Pipeline(memory=None,
#      steps=[('std_scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('svc', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=1.0, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False))])

# %%
plot_decision_boundary(svc_gamma1, axis=[-1.5, 2.5, -1.0, 1.5])
plt.scatter(X[y==0, 0], X[y==0, 1])
plt.scatter(X[y==1, 0], X[y==1, 1])
plt.show()

# %% [markdown]
# ##### gamma=10（过拟合）

# %%
svc_gamma10 = RBFKernelSVC(gamma=10)
svc_gamma10.fit(X, y)
# Out:
# Pipeline(memory=None,
#      steps=[('std_scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('svc', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=10, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False))])

# %%
plot_decision_boundary(svc_gamma10, axis=[-1.5, 2.5, -1.0, 1.5])
plt.scatter(X[y==0, 0], X[y==0, 1])
plt.scatter(X[y==1, 0], X[y==1, 1])
plt.show()

# %% [markdown]
# ##### gamma=0.1（欠拟合）

# %%
svc_gamma01 = RBFKernelSVC(gamma=0.1)
svc_gamma01.fit(X, y)
# Out:
# Pipeline(memory=None,
#      steps=[('std_scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('svc', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.1, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False))])

# %%
plot_decision_boundary(svc_gamma01, axis=[-1.5, 2.5, -1.0, 1.5])
plt.scatter(X[y==0, 0], X[y==0, 1])
plt.scatter(X[y==1, 0], X[y==1, 1])
plt.show()

# %% [markdown]
# # 简单实现SVM解决回归问题

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split

boston = datasets.load_boston()
X = boston.data
y = boston.target

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=666)

# %%
from sklearn.svm import LinearSVR
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

def StdLinearSVR(epsilon=0.1):
    return Pipeline([
        ('std_scaler', StandardScaler()),
        ('linearSVR', LinearSVR(epsilon=epsilon))
    ])

# %%
lin_svr = StdLinearSVR()
lin_svr.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('std_scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('linearSVR', LinearSVR(C=1.0, dual=True, epsilon=0.1, fit_intercept=True,
#      intercept_scaling=1.0, loss='epsilon_insensitive', max_iter=1000,
#      random_state=None, tol=0.0001, verbose=0))])

# %%
lin_svr.score(X_train, y_train)  #简单模拟，并未严格使用CV进行预处理
# Out:
# 0.72553273428792364
